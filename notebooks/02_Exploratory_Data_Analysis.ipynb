# %% [markdown]
# ## Step 01 - EDA and Multiple Choice Questions

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
# Load the CSV file for the present data
present_year_df = pd.read_csv('../data/air_system_present_year.csv')
present_year_df
# Out:
#       class  aa_000 ab_000      ac_000 ad_000 ae_000 af_000 ag_000 ag_001  \
# 0       neg      60      0          20     12      0      0      0      0
# 1       neg      82      0          68     40      0      0      0      0
# 2       neg   66002      2         212    112      0      0      0      0
# 3       neg   59816     na        1010    936      0      0      0      0
# 4       neg    1814     na         156    140      0      0      0      0
# ...     ...     ...    ...         ...    ...    ...    ...    ...    ...
# 15995   neg   81852     na  2130706432    892      0      0      0      0
# 15996   neg      18      0          52     46      8     26      0      0
# 15997   neg   79636     na        1670   1518      0      0      0      0
# 15998   neg     110     na          36     32      0      0      0      0
# 15999   neg       8      0           6      4      2      2      0      0
#
#       ag_002  ...  ee_002  ee_003  ee_004  ee_005   ee_006  ee_007  ee_008  \
# ...

# %%
# Load the CSV file for the previous data
previous_years_df = pd.read_csv('../data/air_system_previous_years.csv')
previous_years_df
# Out:
#       class  aa_000 ab_000      ac_000 ad_000 ae_000 af_000 ag_000 ag_001  \
# 0       neg   76698     na  2130706438    280      0      0      0      0
# 1       neg   33058     na           0     na      0      0      0      0
# 2       neg   41040     na         228    100      0      0      0      0
# 3       neg      12      0          70     66      0     10      0      0
# 4       neg   60874     na        1368    458      0      0      0      0
# ...     ...     ...    ...         ...    ...    ...    ...    ...    ...
# 59995   neg  153002     na         664    186      0      0      0      0
# 59996   neg    2286     na  2130706538    224      0      0      0      0
# 59997   neg     112      0  2130706432     18      0      0      0      0
# 59998   neg   80292     na  2130706432    494      0      0      0      0
# 59999   neg   40222     na         698    628      0      0      0      0
#
#       ag_002  ...   ee_002  ee_003   ee_004   ee_005   ee_006  ee_007  ee_008  \
# ...

# %%
# Basic information about the datasets
print(previous_years_df.info())
print(present_year_df.info())

# Summary statistics
print(previous_years_df.describe())
print(present_year_df.describe())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 60000 entries, 0 to 59999
# Columns: 171 entries, class to eg_000
# dtypes: int64(1), object(170)
# memory usage: 78.3+ MB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16000 entries, 0 to 15999
# Columns: 171 entries, class to eg_000
# dtypes: int64(1), object(170)
# memory usage: 20.9+ MB
# None
#              aa_000
# count  6.000000e+04
# mean   5.933650e+04
# std    1.454301e+05
# min    0.000000e+00
# 25%    8.340000e+02
# 50%    3.077600e+04
# 75%    4.866800e+04
# max    2.746564e+06
#              aa_000
# count  1.600000e+04
# mean   6.799698e+04
# std    5.035350e+05
# min    0.000000e+00
# 25%    9.280000e+02
# 50%    3.098200e+04
# 75%    4.947900e+04
# max    4.294967e+07

# %%
print(previous_years_df.isna().sum())
# Out:
# class     0
# aa_000    0
# ab_000    0
# ac_000    0
# ad_000    0
#          ..
# ee_007    0
# ee_008    0
# ee_009    0
# ef_000    0
# eg_000    0
# Length: 171, dtype: int64

# %%
# List columns
print(previous_years_df.columns)
print(present_year_df.columns)

# Check for common columns
common_columns = set(previous_years_df.columns).intersection(set(present_year_df.columns))
print(f"Common Columns: {common_columns}")
# Out:
# Index(['class', 'aa_000', 'ab_000', 'ac_000', 'ad_000', 'ae_000', 'af_000',
#        'ag_000', 'ag_001', 'ag_002',
#        ...
#        'ee_002', 'ee_003', 'ee_004', 'ee_005', 'ee_006', 'ee_007', 'ee_008',
#        'ee_009', 'ef_000', 'eg_000'],
#       dtype='object', length=171)
# Index(['class', 'aa_000', 'ab_000', 'ac_000', 'ad_000', 'ae_000', 'af_000',
#        'ag_000', 'ag_001', 'ag_002',
#        ...
#        'ee_002', 'ee_003', 'ee_004', 'ee_005', 'ee_006', 'ee_007', 'ee_008',
#        'ee_009', 'ef_000', 'eg_000'],
#       dtype='object', length=171)
# ...

# %%
# Replace 'na' with np.nan and then drop rows with any NaN values
previous_years_df.replace('na', pd.NA, inplace=True)
present_year_df.replace('na', pd.NA, inplace=True)

# Check for missing values and print only columns with missing values
missing_previous = previous_years_df.isna().sum()
missing_present = present_year_df.isna().sum()

print("Columns with missing values in previous_years_df:")
print(missing_previous.sort_values(ascending=False))

print("\nColumns with missing values in present_year_df:")
print(missing_present.sort_values(ascending=False))
# Out:
# Columns with missing values in previous_years_df:
# br_000    49264
# bq_000    48722
# bp_000    47740
# bo_000    46333
# ab_000    46329
#           ...
# cj_000      338
# ci_000      338
# bt_000      167
# aa_000        0
# class         0
# Length: 171, dtype: int64
#
# Columns with missing values in present_year_df:
# br_000    13129
# bq_000    12981
# bp_000    12721
# bo_000    12376
# ab_000    12363
#           ...
# cj_000       86
# ci_000       86
# bt_000       28
# aa_000        0
# class         0
# Length: 171, dtype: int64

# %%
# Drop the 'class' column
previous_years_df = previous_years_df.drop(columns=['class'])
present_year_df = present_year_df.drop(columns=['class'])

# Correlation matrices
previous_corr = previous_years_df.corr()
present_corr = present_year_df.corr()

# Visualize the correlation matrices
plt.figure(figsize=(12, 8))
sns.heatmap(previous_corr, cmap='coolwarm')
plt.title('Correlation Matrix for Previous Years Data')
plt.show()

plt.figure(figsize=(12, 8))
sns.heatmap(present_corr, cmap='coolwarm')
plt.title('Correlation Matrix for Present Year Data')
plt.show()

# %% [markdown]
# ## Multiple Choices Questions

# %%
# Load the CSV file for the present data
previous_years_df = pd.read_csv('../data/air_system_previous_years.csv')
present_year_df = pd.read_csv('../data/air_system_present_year.csv')

# %% [markdown]
# ### 2 - What is the percentage of trucks with defects? (1pt)

# %%
# Concat the dataframes
combined_df = pd.concat([previous_years_df, present_year_df])

# Count the occurrences of 'pos' and 'neg'
pos_count = combined_df['class'].value_counts().get('pos', 0)
neg_count = combined_df['class'].value_counts().get('neg', 0)
total_count = pos_count + neg_count

# Calculate percentages
if total_count > 0:
    pos_percentage = (pos_count / total_count) * 100
    neg_percentage = (neg_count / total_count) * 100
else:
    pos_percentage = neg_percentage = 0

print(f"Percentage of trucks with air system defects (pos): {pos_percentage:.2f}%")
print(f"Percentage of trucks with other defects (neg): {neg_percentage:.2f}%")
# Out:
# Percentage of trucks with air system defects (pos): 1.81%
# Percentage of trucks with other defects (neg): 98.19%

# %% [markdown]
# ### 3 - What are the mean, median, and standard deviation of the column ‘ee_003’ considering null values? (2pt)

# %%
# Replace 'na' with np.nan and then drop rows with any NaN values
previous_years_df.replace('na', pd.NA, inplace=True)
present_year_df.replace('na', pd.NA, inplace=True)

# %%
# Calculate statistics

combined_df = pd.concat([previous_years_df, present_year_df])

# %%
mean_ee_003 = combined_df['ee_003'].mean()
median_ee_003 = combined_df['ee_003'].median()
std_ee_003 = combined_df['ee_003'].std()

print(f"Mean of ee_003: {mean_ee_003}")
print(f"Median of ee_003: {median_ee_003}")
print(f"Standard Deviation of ee_003: {std_ee_003}")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[33], line 1
# ----> 1 mean_ee_003 = combined_df['ee_003'].mean()
#       2 median_ee_003 = combined_df['ee_003'].median()
#       3 std_ee_003 = combined_df['ee_003'].std()
#
# File ~/anaconda3/envs/bixtest/lib/python3.9/site-packages/pandas/core/series.py:6549, in Series.mean(self, axis, skipna, numeric_only, **kwargs)
#    6541 @doc(make_doc("mean", ndim=1))
#    6542 def mean(
#    6543     self,
#    (...)
#    6547     **kwargs,
#    6548 ):
# -> 6549     return NDFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#
# File ~/anaconda3/envs/bixtest/lib/python3.9/site-packages/pandas/core/generic.py:12420, in NDFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#   12413 def mean(
#   12414     self,
#   12415     axis: Axis | None = 0,
#    (...)
#   12418     **kwargs,
#   12419 ) -> Series | float:
# ...

# %% [markdown]
# ### 4 - What are the mean, median, and standard deviation of the column ‘ag_002’ without null values (1pt)?

# %% [markdown]
# ### 5 - What is the Spearman correlation coefficient between the variables ‘ag002’ and ‘ee007’. Don’t consider null values. (2pts)

# %% [markdown]
# ### 6 - What is the Spearman correlation coefficient between the variables ‘ag002’ and ‘ee007’. Don’t consider null values. (2pts)

# %% [markdown]
# ### 7 - What is the value of the column ‘ad_000’ when we group it by ‘class’ and calculate its median without null values: (2pts)

# %% [markdown]
# ### 8 - What is the value of the column ‘ee_001’ when we group it by ‘class’ and calculate its mean without null values: (1pt)

# %% [markdown]
# ### 9 - How many null values are present in the database? (1pt)

# %% [markdown]
# ### 10 - What column is in 4th place when we rank the null values by descending order?
